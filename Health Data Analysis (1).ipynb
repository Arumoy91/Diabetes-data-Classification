# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Health Data.csv')
df
# Out:
#      mduration  sys_BP  dyas_BP  age    Hb   Cr    BMI sex  IHDbinary smoking  \
# 0            1   110.0     80.0   11  10.9  0.7  23.42   M          0      No
# 1            2   100.0     60.0   38  11.5  0.5  25.30   M          0      No
# 2            4   120.0     60.0   17  13.4  0.6  24.01   F          0      No
# 3            2   100.0     60.0   37  12.7  0.7  26.22   M          0      No
# 4            5   100.0     70.0   32  12.3  0.8  23.83   M          0      No
# ..         ...     ...      ...  ...   ...  ...    ...  ..        ...     ...
# 812          4   140.0     80.0   57  12.8  1.1  34.85   M          0      No
# 813          9   140.0     80.0   59  12.3  0.9  30.86   M          0      No
# 814         16   140.0     80.0   65  11.9  1.5  30.04   M          1      No
# 815         10   140.0     80.0   76  10.7  0.9  31.58   M          1      No
# 816         16   150.0    100.0   52  11.4  1.1  31.23   M          0      No
#
#      ...  HLP  Retinopathy  nuropathy  CVA  diabeticfoot  constipation  \
# 0    ...    3            1          2    2             2             2
# 1    ...    2            1          2    2             2             2
# 2    ...    4            1          2    2             2             2
# 3    ...    3            1          2    2             2             2
# 4    ...    4            1          2    2             2             2
# ..   ...  ...          ...        ...  ...           ...           ...
# 812  ...    1            1          1    2             2             2
# 813  ...    3            1          1    2             1             1
# 814  ...    3            3          1    1             2             1
# 815  ...    3            8          1    2             1             1
# 816  ...    3            6          1    1             2             2
#
#      diarrea  dyspepsia  menopose  IHD
# 0          2          2        No   No
# 1          2          1        No   No
# 2          2          2        No   No
# 3          2          1        No   No
# 4          2          1        No   No
# ..       ...        ...       ...  ...
# 812        2          2       Yes   No
# 813        2          1       Yes   No
# 814        2          2       Yes  Yes
# 815        2          2       Yes  Yes
# 816        2          1       Yes   No
#
# [817 rows x 24 columns]

# %%
df.head()
# Out:
#    mduration  sys_BP  dyas_BP  age    Hb   Cr    BMI sex  IHDbinary smoking  \
# 0          1   110.0     80.0   11  10.9  0.7  23.42   M          0      No
# 1          2   100.0     60.0   38  11.5  0.5  25.30   M          0      No
# 2          4   120.0     60.0   17  13.4  0.6  24.01   F          0      No
# 3          2   100.0     60.0   37  12.7  0.7  26.22   M          0      No
# 4          5   100.0     70.0   32  12.3  0.8  23.83   M          0      No
#
#    ...  HLP  Retinopathy  nuropathy  CVA  diabeticfoot  constipation  diarrea  \
# 0  ...    3            1          2    2             2             2        2
# 1  ...    2            1          2    2             2             2        2
# 2  ...    4            1          2    2             2             2        2
# 3  ...    3            1          2    2             2             2        2
# 4  ...    4            1          2    2             2             2        2
#
#    dyspepsia  menopose  IHD
# 0          2        No   No
# 1          1        No   No
# 2          2        No   No
# 3          1        No   No
# 4          1        No   No
#
# [5 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['mduration', 'sys_BP', 'dyas_BP', 'age', 'Hb', 'Cr', 'BMI', 'sex',
#        'IHDbinary', 'smoking', 'addict', 'HYPERTENSIVE', 'nephropathy',
#        'amputation', 'HLP', 'Retinopathy', 'nuropathy', 'CVA', 'diabeticfoot',
#        'constipation', 'diarrea', 'dyspepsia', 'menopose', 'IHD'],
#       dtype='object')

# %%
df.dtypes
# Out:
# mduration         int64
# sys_BP          float64
# dyas_BP         float64
# age               int64
# Hb              float64
# Cr              float64
# BMI             float64
# sex              object
# IHDbinary         int64
# smoking          object
# addict            int64
# HYPERTENSIVE      int64
# nephropathy       int64
# amputation        int64
# HLP               int64
# Retinopathy       int64
# nuropathy         int64
# CVA               int64
# diabeticfoot      int64
# constipation      int64
# diarrea           int64
# dyspepsia         int64
# menopose         object
# IHD              object
# dtype: object

# %%
df.isnull().sum()
# Out:
# mduration       0
# sys_BP          0
# dyas_BP         0
# age             0
# Hb              0
# Cr              0
# BMI             0
# sex             0
# IHDbinary       0
# smoking         0
# addict          0
# HYPERTENSIVE    0
# nephropathy     0
# amputation      0
# HLP             0
# Retinopathy     0
# nuropathy       0
# CVA             0
# diabeticfoot    0
# constipation    0
# diarrea         0
# dyspepsia       0
# menopose        0
# IHD             0
# dtype: int64

# %%
df.shape
# Out:
# (817, 24)

# %%
df.describe()
# Out:
#         mduration      sys_BP     dyas_BP         age          Hb          Cr  \
# count  817.000000  817.000000  817.000000  817.000000  817.000000  817.000000
# mean     8.728274  132.492656   79.313341   54.173807   12.538470    0.896047
# std      6.533443   17.108970    8.867301   10.614532    1.433584    0.296644
# min      1.000000   90.000000   50.000000   11.000000    6.500000    0.500000
# 25%      4.000000  120.000000   70.000000   48.000000   11.700000    0.800000
# 50%      7.000000  130.000000   80.000000   54.000000   12.600000    0.800000
# 75%     12.000000  140.000000   80.000000   61.000000   13.500000    1.000000
# max     37.000000  200.000000  110.000000   92.000000   19.000000    5.700000
#
#               BMI   IHDbinary      addict  HYPERTENSIVE  nephropathy  \
# count  817.000000  817.000000  817.000000    817.000000   817.000000
# mean    30.287099    0.260710    0.011016      0.973072     1.465116
# std      4.945966    0.439291    0.104441      0.161972     0.587091
# min     15.810000    0.000000    0.000000      0.000000     1.000000
# 25%     27.130000    0.000000    0.000000      1.000000     1.000000
# 50%     29.710000    0.000000    0.000000      1.000000     1.000000
# 75%     32.870000    1.000000    0.000000      1.000000     2.000000
# max     52.540000    1.000000    1.000000      1.000000     3.000000
#
#        amputation         HLP  Retinopathy   nuropathy         CVA  \
# count  817.000000  817.000000   817.000000  817.000000  817.000000
# mean     1.013464    2.722154     1.681763    1.402693    1.975520
# std      0.115321    0.810417     1.620661    0.490740    0.154628
# min      1.000000    1.000000     1.000000    1.000000    1.000000
# 25%      1.000000    2.000000     1.000000    1.000000    2.000000
# 50%      1.000000    3.000000     1.000000    1.000000    2.000000
# 75%      1.000000    3.000000     1.000000    2.000000    2.000000
# max      2.000000    4.000000     8.000000    2.000000    2.000000
#
#        diabeticfoot  constipation     diarrea   dyspepsia
# count    817.000000    817.000000  817.000000  817.000000
# mean       1.900857      1.756426    1.982864    1.574051
# std        0.299037      0.429501    0.129857    0.494789
# min        1.000000      1.000000    1.000000    1.000000
# 25%        2.000000      2.000000    2.000000    1.000000
# 50%        2.000000      2.000000    2.000000    2.000000
# 75%        2.000000      2.000000    2.000000    2.000000
# max        2.000000      2.000000    2.000000    2.000000

# %%
dfcorr=df.corr()
dfcorr
# Out:
# C:\Users\WIN 10\AppData\Local\Temp\ipykernel_11944\3531566860.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dfcorr=df.corr()
#               mduration    sys_BP   dyas_BP       age        Hb        Cr  \
# mduration      1.000000  0.099414 -0.089413  0.255678 -0.122164  0.154861
# sys_BP         0.099414  1.000000  0.555111  0.261879  0.065664  0.156949
# dyas_BP       -0.089413  0.555111  1.000000 -0.055863  0.166584  0.025716
# age            0.255678  0.261879 -0.055863  1.000000 -0.052640  0.195737
# Hb            -0.122164  0.065664  0.166584 -0.052640  1.000000 -0.105467
# Cr             0.154861  0.156949  0.025716  0.195737 -0.105467  1.000000
# BMI           -0.081932  0.181624  0.124693 -0.076947  0.007878 -0.067707
# IHDbinary      0.167754  0.194616 -0.013447  0.280422 -0.036767  0.144186
# addict         0.040311 -0.001669  0.021410  0.032540 -0.088776  0.044918
# HYPERTENSIVE   0.030135 -0.148218 -0.243269  0.062601 -0.062561  0.033489
# nephropathy    0.133950  0.203846  0.044357  0.092418 -0.132238  0.278810
# amputation     0.063416 -0.091566 -0.062853 -0.010924 -0.060956  0.058875
# HLP            0.038032  0.009089 -0.010125  0.068162 -0.038055  0.056444
# Retinopathy    0.403619  0.139623 -0.058417  0.105661 -0.145485  0.182621
# nuropathy     -0.142035  0.000718  0.090516 -0.112735  0.217680 -0.005634
# CVA           -0.017510 -0.066773 -0.019425 -0.134043  0.024156 -0.116995
# diabeticfoot  -0.223935  0.003091  0.054480 -0.093789  0.081232 -0.074880
# constipation  -0.145023 -0.048858  0.054655 -0.137472  0.126874 -0.017571
# diarrea       -0.083495 -0.071764 -0.058123 -0.018286  0.025928 -0.110244
# dyspepsia     -0.047220  0.003973 -0.012278 -0.053788  0.090855  0.062989
#
#                    BMI  IHDbinary    addict  HYPERTENSIVE  nephropathy  \
# mduration    -0.081932   0.167754  0.040311      0.030135     0.133950
# sys_BP        0.181624   0.194616 -0.001669     -0.148218     0.203846
# dyas_BP       0.124693  -0.013447  0.021410     -0.243269     0.044357
# age          -0.076947   0.280422  0.032540      0.062601     0.092418
# Hb            0.007878  -0.036767 -0.088776     -0.062561    -0.132238
# Cr           -0.067707   0.144186  0.044918      0.033489     0.278810
# BMI           1.000000  -0.034994 -0.005845      0.027101     0.002318
# IHDbinary    -0.034994   1.000000  0.044169      0.012670     0.089951
# addict       -0.005845   0.044169  1.000000      0.017557     0.076227
# HYPERTENSIVE  0.027101   0.012670  0.017557      1.000000    -0.048553
# nephropathy   0.002318   0.089951  0.076227     -0.048553     1.000000
# amputation   -0.005990   0.075770  0.089420      0.019434     0.070298
# HLP          -0.024734   0.069470 -0.007231     -0.019723     0.011800
# Retinopathy   0.008295   0.207911  0.093138      0.046679     0.159621
# nuropathy    -0.075289  -0.066929 -0.038836     -0.094676    -0.017113
# CVA           0.011172  -0.086342 -0.135050     -0.026352    -0.063416
# diabeticfoot  0.007296  -0.176154 -0.082704      0.020718    -0.113959
# constipation -0.004602  -0.111190 -0.049389     -0.023934    -0.031308
# diarrea       0.001315  -0.114935  0.013935      0.036300    -0.104298
# dyspepsia    -0.049426  -0.024092 -0.027662     -0.082129     0.033161
#
#               amputation       HLP  Retinopathy  nuropathy       CVA  \
# mduration       0.063416  0.038032     0.403619  -0.142035 -0.017510
# sys_BP         -0.091566  0.009089     0.139623   0.000718 -0.066773
# dyas_BP        -0.062853 -0.010125    -0.058417   0.090516 -0.019425
# age            -0.010924  0.068162     0.105661  -0.112735 -0.134043
# Hb             -0.060956 -0.038055    -0.145485   0.217680  0.024156
# Cr              0.058875  0.056444     0.182621  -0.005634 -0.116995
# BMI            -0.005990 -0.024734     0.008295  -0.075289  0.011172
# IHDbinary       0.075770  0.069470     0.207911  -0.066929 -0.086342
# addict          0.089420 -0.007231     0.093138  -0.038836 -0.135050
# HYPERTENSIVE    0.019434 -0.019723     0.046679  -0.094676 -0.026352
# nephropathy     0.070298  0.011800     0.159621  -0.017113 -0.063416
# amputation      1.000000 -0.025487     0.016397  -0.030958  0.018506
# HLP            -0.025487  1.000000     0.053894  -0.100419 -0.034785
# Retinopathy     0.016397  0.053894     1.000000  -0.154549 -0.070247
# nuropathy      -0.030958 -0.100419    -0.154549   1.000000  0.033170
# CVA             0.018506 -0.034785    -0.070247   0.033170  1.000000
# diabeticfoot   -0.210001 -0.053124    -0.148628   0.097022 -0.026049
# constipation    0.016808 -0.018629    -0.144946   0.157775  0.094634
# diarrea         0.015425  0.047862    -0.025944   0.012263  0.040115
# dyspepsia       0.014721  0.028452    -0.016424   0.167245  0.039741
#
#               diabeticfoot  constipation   diarrea  dyspepsia
# mduration        -0.223935     -0.145023 -0.083495  -0.047220
# sys_BP            0.003091     -0.048858 -0.071764   0.003973
# dyas_BP           0.054480      0.054655 -0.058123  -0.012278
# age              -0.093789     -0.137472 -0.018286  -0.053788
# Hb                0.081232      0.126874  0.025928   0.090855
# Cr               -0.074880     -0.017571 -0.110244   0.062989
# BMI               0.007296     -0.004602  0.001315  -0.049426
# IHDbinary        -0.176154     -0.111190 -0.114935  -0.024092
# addict           -0.082704     -0.049389  0.013935  -0.027662
# HYPERTENSIVE      0.020718     -0.023934  0.036300  -0.082129
# nephropathy      -0.113959     -0.031308 -0.104298   0.033161
# amputation       -0.210001      0.016808  0.015425   0.014721
# HLP              -0.053124     -0.018629  0.047862   0.028452
# Retinopathy      -0.148628     -0.144946 -0.025944  -0.016424
# nuropathy         0.097022      0.157775  0.012263   0.167245
# CVA              -0.026049      0.094634  0.040115   0.039741
# diabeticfoot      1.000000      0.078914  0.113990   0.037256
# constipation      0.078914      1.000000  0.012963   0.203196
# diarrea           0.113990      0.012963  1.000000   0.038847
# dyspepsia         0.037256      0.203196  0.038847   1.000000

# %%
sns.displot(df['IHD'])
IHD_percent=round((df['IHD'].value_counts().values[0]/817*100))

# %%
print(df['IHD'].value_counts()/817*100)
# Out:
# No     73.929009
# Yes    26.070991
# Name: IHD, dtype: float64

# %%
plt.figure(figsize=(20,12))
sns.heatmap(df.corr(),cmap='summer')
# Out:
# C:\Users\WIN 10\AppData\Local\Temp\ipykernel_11944\3542323131.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),cmap='summer')
# <Axes: >

# %%
from sklearn.preprocessing import LabelEncoder

def object_to_int(dataframe_series):
    if dataframe_series.dtype=='object':
        dataframe_series = LabelEncoder().fit_transform(dataframe_series)
    return dataframe_series

# %%
df = df.apply(lambda x: object_to_int(x))
df.head()
# Out:
#    mduration  sys_BP  dyas_BP  age    Hb   Cr    BMI  sex  IHDbinary  smoking  \
# 0          1   110.0     80.0   11  10.9  0.7  23.42    1          0        0
# 1          2   100.0     60.0   38  11.5  0.5  25.30    1          0        0
# 2          4   120.0     60.0   17  13.4  0.6  24.01    0          0        0
# 3          2   100.0     60.0   37  12.7  0.7  26.22    1          0        0
# 4          5   100.0     70.0   32  12.3  0.8  23.83    1          0        0
#
#    ...  HLP  Retinopathy  nuropathy  CVA  diabeticfoot  constipation  diarrea  \
# 0  ...    3            1          2    2             2             2        2
# 1  ...    2            1          2    2             2             2        2
# 2  ...    4            1          2    2             2             2        2
# 3  ...    3            1          2    2             2             2        2
# 4  ...    4            1          2    2             2             2        2
#
#    dyspepsia  menopose  IHD
# 0          2         0    0
# 1          1         0    0
# 2          2         0    0
# 3          1         0    0
# 4          1         0    0
#
# [5 rows x 24 columns]

# %%
sns.distplot(df['age'],bins=5)
# Out:
# C:\Users\WIN 10\AppData\Local\Temp\ipykernel_11944\2785783330.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['age'],bins=5)
# <Axes: xlabel='age', ylabel='Density'>

# %%
df.drop(columns=['mduration'], inplace=True)
df.drop(columns=['CVA'], inplace=True)
df.drop(columns=['menopose'], inplace=True)

# %%
df.drop(columns=['IHDbinary'], inplace=True)
df.drop(columns=['amputation'], inplace=True)
df.drop(columns=['Retinopathy'], inplace=True)

# %%
X=df.drop(['IHD'], axis=1)
y=df['IHD']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.30,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# Initialize logistic regression model
logistic_model = LogisticRegression()

# Train the model on the transformed training data
logistic_model.fit(X_train, y_train)

# Predict on the transformed test data
y_pred = logistic_model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7601626016260162
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.93      0.85       181
#            1       0.59      0.29      0.39        65
#
#     accuracy                           0.76       246
#    macro avg       0.69      0.61      0.62       246
# weighted avg       0.73      0.76      0.73       246
# C:\Users\WIN 10\anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import ExtraTreesClassifier

# %%
ad=AdaBoostClassifier()

# %%
ad.fit(X_train, y_train)

# Predict on the transformed test data
y_pred = ad.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7642276422764228
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.94      0.85       181
#            1       0.62      0.28      0.38        65
#
#     accuracy                           0.76       246
#    macro avg       0.70      0.61      0.62       246
# weighted avg       0.74      0.76      0.73       246

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.94      0.85       181
#            1       0.62      0.28      0.38        65
#
#     accuracy                           0.76       246
#    macro avg       0.70      0.61      0.62       246
# weighted avg       0.74      0.76      0.73       246

# %%
cm=confusion_matrix(y_test,ad.predict(X_test))

# %%
print(cm)
# Out:
# [[170  11]
#  [ 47  18]]

# %%
Ra=RandomForestClassifier()

# %%
Ra.fit(X_train, y_train)

# Predict on the transformed test data
y_pred = Ra.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7560975609756098
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.96      0.85       181
#            1       0.62      0.20      0.30        65
#
#     accuracy                           0.76       246
#    macro avg       0.69      0.58      0.58       246
# weighted avg       0.73      0.76      0.71       246

# %%
cm=confusion_matrix(y_test,Ra.predict(X_test))

# %%
print(cm)
# Out:
# [[173   8]
#  [ 52  13]]

# %%
gnb=GaussianNB()

# %%
gnb.fit(X_train, y_train)

# Predict on the transformed test data
y_pred = gnb.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7601626016260162
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.91      0.85       181
#            1       0.58      0.34      0.43        65
#
#     accuracy                           0.76       246
#    macro avg       0.69      0.63      0.64       246
# weighted avg       0.74      0.76      0.74       246

# %%
kc=KNeighborsClassifier()

# %%
kc.fit(X_train, y_train)

# Predict on the transformed test data
y_pred = kc.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7764227642276422
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.93      0.86       181
#            1       0.64      0.35      0.46        65
#
#     accuracy                           0.78       246
#    macro avg       0.72      0.64      0.66       246
# weighted avg       0.76      0.78      0.75       246

# %%
ga= GradientBoostingClassifier()

# %%
ga.fit(X_train, y_train)

# Predict on the transformed test data
y_pred = ga.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7642276422764228
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.93      0.85       181
#            1       0.61      0.29      0.40        65
#
#     accuracy                           0.76       246
#    macro avg       0.70      0.61      0.62       246
# weighted avg       0.74      0.76      0.73       246

# %%
et=ExtraTreesClassifier()

# %%
et.fit(X_train, y_train)

# Predict on the transformed test data
y_pred = et.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.7479674796747967
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.93      0.84       181
#            1       0.55      0.25      0.34        65
#
#     accuracy                           0.75       246
#    macro avg       0.66      0.59      0.59       246
# weighted avg       0.72      0.75      0.71       246

# %%
from sklearn.metrics import roc_curve

# roc curve for models
fpr1, tpr1, thresh1 = roc_curve(y_test, y_pred, pos_label=1)
fpr2, tpr2, thresh2 = roc_curve(y_test, y_pred, pos_label=1)

# roc curve for tpr = fpr 
random_probs = [0 for i in range(len(y_test))]
p_fpr, p_tpr, _ = roc_curve(y_test, random_probs, pos_label=1)

# %%
from sklearn.metrics import roc_auc_score

# auc scores
auc_score1 = roc_auc_score(y_test, y_pred)
auc_score2 = roc_auc_score(y_test, y_pred)

print(auc_score1, auc_score2)
# Out:
# 0.5871653208669784 0.5871653208669784

# %%
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt

# Calculate AUC-ROC score
auc_roc_score = roc_auc_score(y_test, y_pred)

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (AUC = %0.2f)' % auc_roc_score)
plt.plot([0, 1], [0, 1], color='gray', lw=1, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()
